# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
from selenium.webdriver import Chrome   
from selenium.webdriver.common.keys import Keys
import pandas as pd
import time
import re
import requests
import urllib.request #
import datetime as dt

# %%
driver = webdriver.Chrome('./chromedriver')
driver.implicitly_wait(2)
driver.get("https://www.youtube.com/")
driver.implicitly_wait(2)

# %%
#tabsContent > paper-tab.style-scope.ytd-c4-tabbed-header-renderer.iron-selected
def pagedown(num):
    num_of_pagedowns = num #page_down은 2로 놔도 괜찮을 듯 최대화 했으므로
    body = driver.find_element_by_tag_name('body')
    while num_of_pagedowns:
        body.send_keys(Keys.END)
        time.sleep(0.3) #스크롤 속도를 지정할 수 있는 것인데  1.5초가 가장 적당할 듯 1초면 너무 빠름
        #현재는 스크롤을 7번만 하도록 설정되어 있으나 이후에 댓글을 크롤링하기 위해서는 스크롤을 댓글이 안보
        #일때까지 내리면 될텐데 시간이 엄청 오래 걸릴 것임 - 따라서 적당한 수준의 댓글을 크롤링하는것이 좋음
        num_of_pagedowns -= 1

# %%
# brands = ['코웨이','BC카드','에이프릴스킨','제주항공','CJ그룹','유세린','엘페이','일렉트로룩스','코카콜라',
#           '한율','네스카페','쿠빙스','위메프','배스킨라빈스','쏘카','한국화이자제약','토니모리','한화그룹','미니',
#           '롯데푸드','삼성화재','니베아','컴투스','아큐브','엔씨소프트','삼성생명','삼성카드','레킷벤키저',
#           '신한카드','호텔스닷컴','라네즈','롯데카드','삼성전자','롯데리아','버거킹','쉐보레','BMW',
#           '캐논','켈로그','헤라','애플','LG유플러스','SK텔레콤','KT','롯데면세점','동서식품',
#           'SK하이닉스','기아자동차','넷마블','넥슨','현대자동차그룹','G마켓','현대자동차','이니스프리',
#           '삼성전자','배달의민족','SK-II' ,'롯데칠성','빙그레','맥도날드','SK이노베이션','알바천국','리복',
#           '쌤소나이트','뉴트로지나','나이키','플레이스테이션','설화수','현대카드','스니커즈','마몽드','농심','타이레놀',
#           '빈폴','금호타이어','아우디','도미노피자','르노삼성자동차','나이키골프','리스테린','코웨이''LG전자','LG전자',
#           '하이트진로','엔씨소프트','블리자드 엔터테인먼트','에뛰드','아디다스' ,'CJ제일제당','11번가','요기요',
#           '아이오페','소니','처음처럼','유니클로','티몬','한국암웨어','KB국민카드','LG생활건강','카스','SK매직']

# %%
# channels = ['COWAY STORY','Bccard','에이프릴스킨APRILSKIN','Funjejuair','CJ','Eucerin Korea',
#            '엘페이 | 엘포인트','Electrolux Korea','Coca-Cola Korea','한율','NESCAFE Korea','Kuvings',
#            '위메프','배스킨라빈스 Baskinrobbins KOREA','1등 카셰어링쏘카','한국화이자제약','토니모리',
#            '한화 TV [Hanwah TV]','MINI Korea','롯데푸드','Samsungfire Talk','NIVEA Korea',
#            'Com2uS COrp','Acuvue Korea','plaync','삼성생명','삼서카드 Samsung Card',
#            'Reckitt Benckiser Korea','신한카드','Hotels.com APAC','LANEIGE 라네즈 Korea',
#            'Lottecard','Samsung Korea','LOTTE RIA','버거킹','Chevrolet Korea','BMW Korea',
#            'Canon Korea','Kellogg Korea','헤라HERA','Apple 대한민국','LG Uplus','SK telecom',
#            'KT','LOTTE DUTY FREE','커피피라는행복맥심','SK하이닉스','기아자동차','넷마블 TV','넥슨 YouTube',
#            '현대자동차그룹','GmarketZone','이니스프리','삼성전자 뉴스룸','배달의민족','SK-2 korea',
#            'LOTTE CHILSUNG', '빙그레', '한국 맥도날드', 'SK이노베이션','알바천국','Reebok Korea',
#            'Korea Samsonite','Neutrogena Korea','Nike Korea','PlayStation Korea','Sulshasoo 설화수',
#            '현대카드','SNICKERS','MAMONDE 마몽드 KOREA','nongshim','Tylenol Korea','BEANPOLE 빈폴',
#            '금호타이어 엑스타TV','Audi Korea아우디 코리아','도미노피자','renaultsamsungM',
#            '나이키 골프 코리아 유튜브','Listerinekorea','COWAY STORY''LGMobile KR',
#            'LG전자 LG Electronics korea','HITEJINRO','ncsoft','BLIZZAREDKOREA',
#            '에뛰드하우스(ETUDE HOUSE)','adidas Korea','CJ제일제당(CJ Cheiljedang)','11번가',
#            '요기요(YogiyoKr)','아이오페(IOPE)','Sony Korea','처음처럼','코리아유니클로','티몬 TMON Official',
#            'Amway Korea','KB국민카드','LGCAREAD','Cass TVC','SK매직']

# %%
channels = ['COWAY STORY','Bccard','에이프릴스킨APRILSKIN','Funjejuair','CJ','Eucerin Korea',
            '엘페이 | 엘포인트','Electrolux Korea','Coca-Cola Korea','한율','NESCAFE Korea','Kuvings',
            '위메프','배스킨라빈스 Baskinrobbins KOREA','1등 카셰어링쏘카','한국화이자제약','토니모리',
            '한화 TV [Hanwah TV]','MINI Korea','롯데푸드']
channel = []
subscribers_list = []
totalview_list = []
videonums_list = []
videoviewsmeans_list = []

# %%
youtube = pd.DataFrame({'channel':[],
                        'subscribers_list':[],
                        'totalview_list':[],
                        'videonums_list':[],
                        'videoviewsmeans_list':[]})

for i in channels:
    search = driver.find_element_by_name("search_query")
    search.clear()
    search.send_keys(i)
    search.submit()
    driver.find_element_by_id("avatar-section").click()
    subscriber = driver.find_element_by_id("subscriber-count")
    if len(subscriber.text) > 0:
        subscribers_list = (subscriber.text)
    else:
        subscribers_list = 'NaN'
    driver.find_element_by_xpath('//*[@id="tabsContent"]/paper-tab[6]/div').click()
    totalviews = driver.find_element_by_xpath('//*[@id="right-column"]/yt-formatted-string[3]').text
    totalview_list = totalviews
    
    viwes = []
    driver.find_element_by_xpath('//*[@id="tabsContent"]/paper-tab[2]/div').click()
    time.sleep(3)
    pagedown(50)
    page = driver.page_source
    soup = bs(page, 'lxml')
    all_videos = soup.find_all(id='dismissable')
    videonums_list = len(all_videos)
    videoviewsmeans_list = str(int(totalviews.strip('조회수 ').replace(',','')) / len(all_videos)) + ' 회'
    
    insert_data = pd.DataFrame({'channel':[i],
                                'subscribers_list':[subscribers_list],
                                'totalview_list':[totalview_list],
                                'videonums_list':[videonums_list],
                                'videoviewsmeans_list':[videoviewsmeans_list]})
    
    youtube = youtube.append(insert_data)
    
    
youtube.index = range(len(youtube))

                              
print('누적 조회수: ', totalview_list)
print('구독자 수: ', subscribers_list)
print('동영상 수: ', videonums_list)
print('동영상 평균 조회수: ', videoviewsmeans_list)
# Out:
# 누적 조회수:  조회수 37,138,996회
# 구독자 수:  구독자 1.09만명
# 동영상 수:  325
# 동영상 평균 조회수:  114273.83384615385 회

# %%
youtube
# Out:
#                        channel subscribers_list   totalview_list  \
# 0                  COWAY STORY              NaN  조회수 51,443,590회
# 1                       Bccard       구독자 10.8만명  조회수 41,387,789회
# 2              에이프릴스킨APRILSKIN       구독자 8.06만명  조회수 26,195,638회
# 3                   Funjejuair       구독자 2.43만명  조회수 37,637,705회
# 4                           CJ              NaN  조회수 30,047,695회
# 5                Eucerin Korea       구독자 1.15만명  조회수 36,619,514회
# 6                   엘페이 | 엘포인트       구독자 5.58만명   조회수 7,239,999회
# 7             Electrolux Korea        구독자 1.1만명  조회수 25,865,884회
# 8              Coca-Cola Korea       구독자 5.09만명  조회수 91,310,525회
# 9                           한율       구독자 1.04만명  조회수 38,582,874회
# 10               NESCAFE Korea       구독자 6.29천명  조회수 48,375,819회
# 11                     Kuvings       구독자 1.49만명  조회수 25,472,534회
# 12                         위메프              NaN  조회수 30,547,677회
# ...

# %%
youtube.to_excel(excel_writer = './youtube.xlsx',
                 sheet_name = 'data',
                 header = True,
                 index = False)
